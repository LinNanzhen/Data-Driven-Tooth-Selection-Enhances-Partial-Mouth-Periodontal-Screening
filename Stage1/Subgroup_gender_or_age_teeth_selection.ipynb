# %%
from pathlib import Path
from scenarios.subgroup_single_factor import build_config, build_groups, run

config = build_config(Path('.'))
groups = build_groups()
result = run(config, groups)
result.summary.head()
